# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_junin=pd.read_excel("Datos_junin.xlsx")
df_junin
# Out:
#       Cultivo  idDepartamento  Sup_Sembrada  Sup_Cosechada  Producción  \
# 0         101             210            35             35          56
# 1         101             462            50             50          70
# 2         101             462            50             50          40
# 3         101             469           150            130         190
# 4         101             469           120            120         168
# ...       ...             ...           ...            ...         ...
# 1449      129             714         30530          30530      140438
# 1450      129             714         32705          32705      160255
# 1451      129             714         35300          33718      144987
# 1452      129             714         35100          35100      147420
# 1453      129             714         32499          31901      165885
#
#       Rendimiento  anio  Precipitacion
# 0            1600  2021          257.7
# ...

# %%
df_tres_arroyos=pd.read_excel("Datos_tres_arroyos.xlsx")
df_tres_arroyos
# Out:
#       Cultivo  anio  idDepartamento  Sup_Sembrada  Sup_Cosechada  Producción  \
# 0         101  1988              14          3000           3000        2250
# 1         101  1989              14          2000           2000        2400
# 2         101  1990              14          1800           1700        1700
# 3         101  1991              14          1000           1000         950
# 4         101  1992              14          2000           2000        2200
# ...       ...   ...             ...           ...            ...         ...
# 1925      129  2017             833        105070         105070      514843
# 1926      129  2018             833         89875          80875      339453
# 1927      129  2019             833        119000         119000      393100
# 1928      129  2020             833        131000         131000      570000
# 1929      129  2021             833        117946         117946      484392
#
#       Rendimiento  Precipitacion
# ...

# %%
df_Total= pd.concat([df_junin, df_tres_arroyos], axis=0)

# %%
df_Total.to_excel("Datos_totales.xlsx")

# %%
df_Total
# Out:
#       Cultivo  idDepartamento  Sup_Sembrada  Sup_Cosechada  Producción  \
# 0         101             210            35             35          56
# 1         101             462            50             50          70
# 2         101             462            50             50          40
# 3         101             469           150            130         190
# 4         101             469           120            120         168
# ...       ...             ...           ...            ...         ...
# 1925      129             833        105070         105070      514843
# 1926      129             833         89875          80875      339453
# 1927      129             833        119000         119000      393100
# 1928      129             833        131000         131000      570000
# 1929      129             833        117946         117946      484392
#
#       Rendimiento  anio  Precipitacion
# 0            1600  2021          257.7
# ...
