# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df_definitivo = pd.read_csv("data.csv", encoding='latin-1', sep=",", low_memory=False)
df_definitivo
# Out:
#         Unnamed: 0  precipitacion CampaÃ±a    mes      Cultivo     Provincia  \
# 0                0           56.2  1987/88  enero          Ajo  BUENOS AIRES
# 1                1           56.2  1987/88  enero          Ajo  BUENOS AIRES
# 2                2           56.2  1987/88  enero          Ajo  BUENOS AIRES
# 3                3           56.2  1987/88  enero          Ajo  BUENOS AIRES
# 4                4           56.2  1987/88  enero          Ajo  BUENOS AIRES
# ...            ...            ...      ...    ...          ...           ...
# 263841      263841            NaN  2019/20    NaN  Trigo total  BUENOS AIRES
# 263842      263842            NaN  2019/20    NaN  Trigo total  BUENOS AIRES
# 263843      263843            NaN  2019/20    NaN  Trigo total  BUENOS AIRES
# 263844      263844            NaN  2019/20    NaN  Trigo total  BUENOS AIRES
# 263845      263845            NaN  2019/20    NaN  Trigo total  BUENOS AIRES
#
# ...

# %%
df_definitivo['Rendimiento'].replace('SD', '0', inplace=True)
df_definitivo.Rendimiento = df_definitivo.Rendimiento.astype(float)
df_definitivo["Sup_Cosechada"].replace('SD', '0', inplace=True)
df_definitivo["Sup_Cosechada"] = df_definitivo["Sup_Cosechada"].astype(float)

# %%
df_localidad = df_definitivo[df_definitivo.Departamento.isin(["SALTO", "CHACABUCO","ARENALES","ROJAS","LEANDRO N. ALEM","LINCOLN","JUNIN"])]
df_localidad
# Out:
#         Unnamed: 0  precipitacion CampaÃ±a    mes      Cultivo     Provincia  \
# 29              29           56.2  1987/88  enero      Alpiste  BUENOS AIRES
# 30              30           56.2  1987/88  enero      Alpiste  BUENOS AIRES
# 39              39           56.2  1987/88  enero      Alpiste  BUENOS AIRES
# 70              70           56.2  1987/88  enero        Avena  BUENOS AIRES
# 100            100           56.2  1987/88  enero        Avena  BUENOS AIRES
# ...            ...            ...      ...    ...          ...           ...
# 263796      263796            NaN  2019/20    NaN  Trigo total  BUENOS AIRES
# 263800      263800            NaN  2019/20    NaN  Trigo total  BUENOS AIRES
# 263801      263801            NaN  2019/20    NaN  Trigo total  BUENOS AIRES
# 263825      263825            NaN  2019/20    NaN  Trigo total  BUENOS AIRES
# 263830      263830            NaN  2019/20    NaN  Trigo total  BUENOS AIRES
#
# ...

# %%
df_localidad = df_localidad.rename(columns={'CampaÃ±a':'Campaña',
                                   'ProducciÃ³n':'Produccion', "mes":"Mes", "precipitacion":"Precipitacion mensual"})

# %%
df_localidad = df_localidad.drop(columns = ["Unnamed: 0"]) 
df_localidad
# Out:
#         Precipitacion mensual  Campaña    Mes      Cultivo     Provincia  \
# 29                       56.2  1987/88  enero      Alpiste  BUENOS AIRES
# 30                       56.2  1987/88  enero      Alpiste  BUENOS AIRES
# 39                       56.2  1987/88  enero      Alpiste  BUENOS AIRES
# 70                       56.2  1987/88  enero        Avena  BUENOS AIRES
# 100                      56.2  1987/88  enero        Avena  BUENOS AIRES
# ...                       ...      ...    ...          ...           ...
# 263796                    NaN  2019/20    NaN  Trigo total  BUENOS AIRES
# 263800                    NaN  2019/20    NaN  Trigo total  BUENOS AIRES
# 263801                    NaN  2019/20    NaN  Trigo total  BUENOS AIRES
# 263825                    NaN  2019/20    NaN  Trigo total  BUENOS AIRES
# 263830                    NaN  2019/20    NaN  Trigo total  BUENOS AIRES
#
#            Departamento  idProvincia  idDepartamento  Sup_Sembrada  \
# ...
